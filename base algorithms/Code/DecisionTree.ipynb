# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Malicious Macro Detection
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/Malicious Macro Detection
#  AdaBoostClassifier.joblib
#  classifiers_recall_scores.joblib
#  CNNClassifier.joblib
#  DecisionTreeClassifier.joblib
#  EDA.ipynb
#  features_k_1000.joblib
#  features_k_100.joblib
#  features_k_10.joblib
#  features_k_1200.joblib
#  features_k_1500.joblib
#  features_k_2000.joblib
#  features_k_2500.joblib
#  features_k_3000.joblib
#  features_k_500.joblib
#  features_k_50.joblib
#  gnbClassifier.joblib
#  GradientBoostingClassifier.joblib
#  knnClassifier.joblib
#  LSTMClassifier.joblib
# 'Macro Malware Detection using Machine Learning Techniques A New Approach '
#  mlpClasifier.joblib
#  __pycache__/
#  randomForestClassifier.joblib
#  recall_scores.joblib
#  RobertaClassifier.joblib
#  svmClassifier.joblib
#  test_dataset.csv
#  test_loader.joblib
#  test_loader.pkl
#  tfidf_1000.joblib
#  tfidf_100.joblib
#  tfidf_10.joblib
#  tfidf_1200.joblib
#  tfidf_1500.joblib
#  tfidf_2000.joblib
#  tfidf_2500.joblib
#  tfidf_3000.joblib
#  tfidf_500.joblib
#  tfidf_50.joblib
#  train_dataset.csv
#  trainer.joblib
#  train_loader.joblib
#  train_loader.pkl
#  utils.py
#  validation_dataset.csv
#  val_loader.joblib
#  val_loader.pkl
#  vba_pipeline.py
#  word2vec_model.joblib
#  word2vec_model.pkl
#  x_test_1000.joblib
#  x_test_100.joblib
#  x_test_10.joblib
#  x_test_1200.joblib
#  x_test_1500.joblib
#  x_test_2000.joblib
#  x_test_2500.joblib
#  x_test_3000.joblib
#  x_test_500.joblib
#  x_test_50.joblib
#  x_train_1000.joblib
#  x_train_100.joblib
#  x_train_10.joblib
#  x_train_1200.joblib
#  x_train_1500.joblib
#  x_train_2000.joblib
#  x_train_2500.joblib
#  x_train_3000.joblib
#  x_train_500.joblib
#  x_train_50.joblib

# %%
from vba_pipeline import *
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from utils import save_loader

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import make_scorer, recall_score
from sklearn.model_selection import GridSearchCV
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

from vba_pipeline import create_pipeline, evaluate_model

# %%
param_grid_dt = {
    'model__criterion': ['gini', 'entropy'],
    'model__max_depth': [None, 10, 20, 30]
}

mapper = {
    'white' : 1,
    'mal' : 0
}

# %%
train_set = pd.read_csv('train_dataset.csv', encoding='utf-16le')
val_set = pd.read_csv('validation_dataset.csv', encoding='utf-16le')
test_set = pd.read_csv('test_dataset.csv', encoding='utf-16le')

# %%
x_train, y_train = train_set['vba_code'], train_set['label']
x_val, y_val = val_set['vba_code'], val_set['label']
x_test, y_test = test_set['vba_code'], test_set['label']

y_train = y_train.map(mapper)
y_val = y_val.map(mapper)
y_test = y_test.map(mapper)

# %%
dt_pipeline = create_pipeline(DecisionTreeClassifier(), TfidfVectorizer())

# %%
scorer = make_scorer(recall_score, average='binary')

grid_search_dt = GridSearchCV(estimator=dt_pipeline, param_grid=param_grid_dt, scoring=scorer, cv=5)

grid_search_dt
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         <vba_pipeline.PreprocessTransformer object at 0x7b8210b63ac0>),
#                                        ('vectorizer', TfidfVectorizer()),
#                                        ('scaler',
#                                         StandardScaler(with_mean=False)),
#                                        ('model', DecisionTreeClassifier())]),
#              param_grid={'model__criterion': ['gini', 'entropy'],
#                          'model__max_depth': [None, 10, 20, 30]},
#              scoring=make_scorer(recall_score, response_method='predict', average=binary))

# %%
grid_search_dt.fit(x_train, y_train)

print("Best parameters found: ", grid_search_dt.best_params_)
print("Best recall score: ", grid_search_dt.best_score_)
# Out:
# Best parameters found:  {'model__criterion': 'entropy', 'model__max_depth': 10}
# Best recall score:  0.9921631925907011

# %%
best_params = grid_search_dt.best_params_
dt_params = {k.replace('model__', ''): v for k, v in best_params.items()}
dt_model = DecisionTreeClassifier(**dt_params)

x_train_tfidf_1000 = load('x_train_1000.joblib')

dt_model.fit(x_train_tfidf_1000, y_train)

# %%
save_loader('/content/drive/MyDrive/Colab Notebooks/Malicious Macro Detection/DecisionTreeClassifier.joblib', dt_model)
